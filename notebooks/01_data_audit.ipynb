# %% [markdown]
# # 01 — Auditoria dos Dados (WP1A, Etapa 1)
#
# Segue `docs/specs/SPEC-001-data-audit.md` e `.agents/skills/data-audit/SKILL.md`.
#
# Produz a Entrega A1 (`reports/audit/`).
#
# **Status: não implementado.** Este notebook é um esqueleto — nenhum código de
# pipeline foi escrito ainda. Ao implementar, valide cada dataset carregado com
# `src/wp1a/data/schema.py::validate_schema` antes de prosseguir.

# %% [markdown]
# ## TODO
#
# 1. Listar arquivos disponíveis em `data/raw/`.
# 2. Contar linhas/colunas por arquivo.
# 3. Documentar nomes, tipos e significado das variáveis.
# 4. Calcular distribuição das 21 classes.
# 5. Calcular execuções (`run`) por classe.
# 6. Verificar valores ausentes/infinitos/inconsistentes.
# 7. Verificar duplicações.
# 8. Verificar relação arquivo–classe–`run_id`.
#
# Ver a lista completa de requisitos verificáveis em `docs/specs/SPEC-001-data-audit.md` §3.
