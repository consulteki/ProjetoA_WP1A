# %% [markdown]
# # 03 — Análise de Resultados (WP1A, pós-Etapa 6)
#
# Segue `docs/specs/SPEC-007-evaluation.md`, `docs/specs/SPEC-008-statistics.md` e
# `docs/specs/SPEC-009-publication.md`.
#
# Consome a Entrega A5 (`results/metrics/`) e produz insumos para A6
# (`article/figures/`, `article/tables/`).
#
# **Status: não implementado.** Requer que os 6 modelos tenham sido treinados e
# avaliados (Etapas 5–6) sob o protocolo comum (`docs/adr/ADR-006`). Nenhuma
# conclusão de "melhor modelo" pode se basear em métrica única
# (`docs/adr/ADR-007-multi-criteria-model-evaluation.md`).

# %% [markdown]
# ## TODO
#
# 1. Carregar métricas completas dos 6 modelos (`results/metrics/`).
# 2. Construir tabela comparativa de métricas globais e por classe.
# 3. Gerar matrizes de confusão e identificar falhas mais confundidas (QP3).
# 4. Rodar comparação estatística formal (Friedman + pós-hoc; Wilcoxon + correção) —
#    ver `.agents/skills/statistical-analysis/SKILL.md`.
# 5. Cruzar desempenho × custo computacional (QP4/QP5).
# 6. Avaliar H1–H4 explicitamente, com base no conjunto de teste.
#
# Ver `docs/project/research_questions.md` e `docs/project/hypotheses.md` para as
# perguntas e hipóteses a responder.
